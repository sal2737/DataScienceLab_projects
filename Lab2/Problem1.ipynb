# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# read in data

# %%
df1 = pd.read_csv('DF1.csv')

# %% [markdown]
# check that data is properly imported

# %%
print(df1)
# Out:
#         id         1       1.1         2         3
# 0        0  1.038502  0.899865  0.835053 -0.971528
# 1        1  0.320455 -0.647459  0.149079  0.352593
# 2        2  0.055480  2.234771  0.271672 -2.108739
# 3        3 -0.007260 -0.524299 -0.126550  0.670827
# 4        4 -1.237390 -1.377017 -1.049932  1.342079
# 5        5  0.477841  0.032660  0.336723 -0.171675
# 6        6 -0.486923 -1.128336 -0.459850  1.113013
# 7        7  0.313020  0.677323  0.123082 -0.617958
# 8        8  0.919790 -0.539665  0.956577  0.821389
# 9        9  0.574238 -1.024339  0.471622  1.006623
# 10      10 -0.745211  1.117401 -0.955933 -1.128786
# 11      11 -0.472249  1.819872 -0.660452 -1.782977
# 12      12  0.426001  1.501646  0.275335 -1.466056
# 13      13  1.529169  1.964452  1.485045 -1.950166
# 14      14  0.454290 -0.643795  0.417083  0.623628
# 15      15  2.225789 -0.015177  2.123942  0.125185
# 16      16  0.325455 -0.679482  0.589621  0.849904
# ...

# %% [markdown]
# make matplotlib output inline to show up in notebook

# %%
# %matplotlib inline

# %% [markdown]
# Let's start by exploring the data! As seen below, it appears column 1 and column 2 are not correlated.

# %%
df1.plot(x = 1, y = 2, kind = 'scatter')

# %% [markdown]
# Pairwise, columns 2 and 3, columns 3 and 4, and columns 1 and 4 are not correlated.

# %%
df1.plot(x = 2, y = 3, kind = 'scatter')

# %%
df1.plot(x = 3, y = 4, kind = 'scatter')

# %%
df1.plot(x = 1, y = 4, kind = 'scatter')

# %% [markdown]
# However, columns 1 and  3 look to be positively correlated! Columns 2 and 4 appear to be negatively correlated.

# %%
df1.plot(x = 1, y = 3, kind = 'scatter')

# %%
df1.plot(x = 2, y = 4, kind = 'scatter')
